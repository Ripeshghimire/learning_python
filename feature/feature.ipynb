# %%
data = [
    {'price':85000,'rooms':4,'neighborhood':'Jawalakhel'},
    {'price':70000,'rooms':3,'neighborhood':'Kopundole'},
    {'price':65000,'rooms':3,'neighborhood':'Kapan'},
    {'price':60000,'rooms':2,'neighborhood':'Kopundole'},
]
newData  = {'Jawalakhel':1,'Kupondole':2,'Kapan':1}

import numpy as np 
from sklearn.feature_extraction import DictVectorizer
vec = DictVectorizer(sparse=False,dtype=int)
newData = vec.fit_transform(data)
vec.get_feature_names_out()
# Out:
# array(['neighborhood=Jawalakhel', 'neighborhood=Kapan',
#        'neighborhood=Kopundole', 'price', 'rooms'], dtype=object)

# %%
import numpy as np 
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
x = np.array([1,2,3,4,5])
y = np.array([4,2,1,3,7])
plt.scatter(x,y)
plt.show()

# %%
X = x[:,np.newaxis]
model = LinearRegression()
model.fit(X,y)
ypred = model.predict(X)
plt.scatter(x,y)
plt.plot(x,ypred)
plt.show()

# %%
from sklearn.preprocessing import PolynomialFeatures
poly = PolynomialFeatures(degree =10)
X2 = poly.fit_transform(X)
model = LinearRegression()
model.fit(X2,y)
yfilt = model.predict(X2)
plt.scatter(x,y)
plt.plot(x,yfilt)
plt.show()

# %%
# TextFeature Extraction 
import pandas as pd 
sample = ['problem of evil','evil queen','horizon problem']

# %%
from sklearn.feature_extraction.text import CountVectorizer
vec = CountVectorizer()
x = vec.fit_transform(sample)
print(x)
# Out:
#   (0, 3)	1
#   (0, 2)	1
#   (0, 0)	1
#   (1, 0)	1
#   (1, 4)	1
#   (2, 3)	1
#   (2, 1)	1

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
vec2 = TfidfVectorizer()
y = vec2.fit_transform(sample)
y
data1 = pd.DataFrame(y.toarray(), columns = vec.get_feature_names_out())
data1
# Out:
#        evil   horizon        of   problem     queen
# 0  0.517856  0.000000  0.680919  0.517856  0.000000
# 1  0.605349  0.000000  0.000000  0.000000  0.795961
# 2  0.000000  0.795961  0.000000  0.605349  0.000000
